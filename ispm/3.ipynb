# %% [markdown]
# <a href="https://colab.research.google.com/github/Wayodeni/university/blob/main/ispm/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание №3. Формирование иерархической структуры проекта в контексте управления проектами информационных систем**

# %% [markdown]
# ```
# 1. ОБЗОР ПРЕДМЕТНОЙ ОБЛАСТИ И СУЩЕСТВУЮЩИХ РЕШЕНИЙ
#   1.1. Исследование текущего состояния предметной области
#     1.1.1. Особенности ледовой обстановки и задачи её анализа
#     1.1.2. Использование данных дистанционного зондирования Земли (ДЗЗ)
#     1.1.3. Методы сегментации и классификации изображений (в том числе спутниковых)
#   1.2. Обзор существующих систем и приложений
#     1.2.1. Специализированные ледовые сервисы и платформы
#     1.2.2. Геоинформационные и EO-платформы
#     1.2.3. Системы на основе методов машинного обучения
#   1.3. Обзор технологий и инструментов разработки
#     1.3.1. Языки программирования и библиотеки для обработки изображений
#     1.3.2. Фреймворки для создания веб-приложений
#     1.3.3. Инструменты работы с геопространственными данными
# 2. АНАЛИЗ И ФОРМИРОВАНИЕ ТРЕБОВАНИЙ К СИСТЕМЕ
#   2.1. Анализ недостатков существующих решений
#     2.1.1. Функциональные ограничения (отсутствие единого workflow)
#     2.1.2. Ограничения пользовательского интерфейса и сложности использования
#     2.1.3. Ограничения в сегментации, классификации и анализе ROI
#   2.2. Выбор технологического стека
#     2.2.1. Обоснование выбора языка программирования (Python)
#     2.2.2. Обоснование выбора фреймворка (Streamlit)
#     2.2.3. Выбор библиотек для обработки изображений и машинного обучения
#   2.3. Формирование требований к системе
#     2.3.1. Функциональные требования
#       - загрузка и отображение изображений
#       - выделение области интереса (ROI)
#       - сегментация ледового покрова
#       - классификация типов льда
#       - расчет статистики
#     2.3.2. Нефункциональные требования
#       - производительность
#       - удобство использования
#       - масштабируемость
#       - надежность
#     2.3.3. Пользовательские сценарии
#       - сценарий анализа ROI
#       - сценарий получения статистики
#       - сценарий визуализации результатов
#
# 3. ПРОЕКТИРОВАНИЕ И РЕАЛИЗАЦИЯ СИСТЕМЫ
#   3.1. Проектирование архитектуры системы
#     3.1.1. Общая архитектура веб-приложения
#     3.1.2. Проектирование модулей системы
#     - модуль загрузки данных
#     - модуль обработки изображений
#     - модуль сегментации и классификации
#     - модуль визуализации
#
#     3.1.3. UML-диаграммы
#
#   3.2. Программная реализация
#     3.2.1. Реализация алгоритмов сегментации и классификации
#     3.2.2. Реализация обработки ROI
#     3.2.3. Разработка пользовательского интерфейса (Streamlit)
#     3.2.4. Визуализация результатов и статистики
#   3.3. Внедрение и тестирование
#     3.3.1. Развёртывание системы
#     3.3.2. Функциональное тестирование
#     3.3.3. Оценка качества сегментации и классификации
#     3.3.4. Оценка производительности системы
# 4. ОЦЕНКА ЭФФЕКТИВНОСТИ И РЕЗУЛЬТАТОВ РАЗРАБОТКИ
#   4.1. Анализ полученных результатов
#   4.2. Сравнение с существующими решениями
#   4.3. Преимущества и ограничения разработанной системы
# 5. ЗАКЛЮЧЕНИЕ
#   5.1. Основные результаты работы
#   5.2. Перспективы развития системы
# ```
